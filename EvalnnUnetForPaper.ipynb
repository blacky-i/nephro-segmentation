# %%
# !git clone https://github.com/MIC-DKFZ/nnUNet.git

# %%
# !cd nnUNet && git checkout v1.7.0 && pip install -e .

# %%
import os
curr = os.getcwd()
# %set_env nnUNet_raw_data_base=$curr/nnUNet_paper
# %set_env nnUNet_preprocessed=$curr/nnUNet_preprocessed_paper
# %set_env RESULTS_FOLDER=$curr/nnUNet_trained_models

# %% [markdown]
# ## Download pretrained KiTS21 model

# %%
# !pip install zenodo_get
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting zenodo_get
#   Downloading zenodo_get-1.3.4-py2.py3-none-any.whl (17 kB)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from zenodo_get) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->zenodo_get) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->zenodo_get) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->zenodo_get) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->zenodo_get) (2.0.12)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=99b02050b05d8b624114877b059946d642559d7d1290388c6e9f0cb26c675102
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, zenodo_get
# Successfully installed wget-3.2 zenodo_get-1.3.4

# %%
# !zenodo_get 5126443
# Out:
# Title: pretrained nnU-Net weights for KiTS21
# Keywords:
# Publication date: 2021-07-23
# DOI: 10.5281/zenodo.5126443
# Total size: 3372.5 MB
#
# Link: https://zenodo.org/api/files/f08f8382-b8e0-4c2f-8633-8407d8a9188e/nnU-Net_trainingSet_predicted.zip   size: 29.1 MB
#
# Checksum is correct. (d01e8a7f0876150b667aea68873de0e6)
#
# Link: https://zenodo.org/api/files/f08f8382-b8e0-4c2f-8633-8407d8a9188e/Task135_KiTS2021.zip   size: 3343.4 MB
#
# Checksum is correct. (b27ab702742083080b95baac00ba186f)
# All files have been downloaded.

# %%
# !nnUNet_install_pretrained_model_from_zip Task135_KiTS2021.zip
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet

# %%
import requests
from urllib.parse import urlencode

base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
public_key = 'https://disk.yandex.ru/d/pWEKt6D3qi3-aw'

final_url = base_url + urlencode(dict(public_key=public_key))
response = requests.get(final_url)
download_url = response.json()['href']
response = requests.get(download_url)

dist_path = 'AVUCTK_cases.zip'
with open(dist_path, 'wb') as f:
    f.write(response.content)
    
import zipfile
with zipfile.ZipFile(dist_path, 'r') as zip_ref:
    zip_ref.extractall()

# %%
import gzip
import shutil
import os

nn_unet_data_dir = 'kidney_raw'
os.makedirs(nn_unet_data_dir, exist_ok=True)

for case_dir in os.listdir('data'):
  curr_file = os.path.join('data',case_dir,'12.nii.gz')
  shutil.copy2(curr_file,f'{nn_unet_data_dir}/{case_dir}_0000.nii.gz')

# %% [markdown]
# ### Run inference
#
# Reads kidney_raw directory and creates masks

# %%
# !nnUNet_predict -t Task135_KiTS2021 -f 0 -i kidney_raw -o kidney_paper_out_lowres -m 3d_lowres
# !nnUNet_predict -t Task135_KiTS2021 -f 0 -i kidney_raw -o kidney_paper_out_fullres -m 3d_fullres
# !nnUNet_predict -t Task135_KiTS2021 -f 0 -i kidney_raw -o kidney_paper_out_cascade -m 3d_cascade_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet_trained_models/nnUNet/3d_lowres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 9 unique case ids, here are some examples: ['case_8' 'case_4' 'case_8' 'case_6' 'case_8' 'case_4' 'case_2' 'case_1'
#  'case_4']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 9
# number of cases that still need to be predicted: 9
# emptying cuda cache
# loading parameters for folds, [0]
# using the following model files:  ['/content/nnUNet_trained_models/nnUNet/3d_lowres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing kidney_paper_out_lowres/case_1.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_lowres/case_2.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_lowres/case_3.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_lowres/case_4.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_lowres/case_5.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_lowres/case_6.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 136, 135, 248) after crop: (1, 136, 135, 248) spacing: [1.         0.97655976 0.97656274]
#
# no separate z, order 3
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# before crop: (1, 145, 198, 296) after crop: (1, 145, 198, 296) spacing: [1.25000215 0.8437497  0.84375256]
#
# before crop: (1, 208, 161, 307) after crop: (1, 208, 161, 307) spacing: [0.79999989 0.71700001 0.71699935]
#
# no separate z, order 3
# no separate z, order 3
# before crop: (1, 249, 176, 290) after crop: (1, 249, 176, 290) spacing: [0.69999993 0.84765714 0.84765399]
#
# no separate z, order 3
# no separate z, order 1
# before crop: (1, 217, 190, 321) after crop: (1, 217, 190, 321) spacing: [0.79999965 0.78100002 0.78099996]
#
# no separate z, order 3
# before: {'spacing': array([1.        , 0.97655976, 0.97656274]), 'spacing_transposed': array([0.97656274, 1.        , 0.97655976]), 'data.shape (data is transposed)': (1, 248, 136, 135)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 122, 68, 66)}
#
# (1, 122, 68, 66)
# preprocessing kidney_paper_out_lowres/case_7.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_lowres/case_1.nii.gz
# no separate z, order 3
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.25000215, 0.8437497 , 0.84375256]), 'spacing_transposed': array([0.84375256, 1.25000215, 0.8437497 ]), 'data.shape (data is transposed)': (1, 296, 145, 198)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 125, 91, 84)}
#
# (1, 125, 91, 84)
# no separate z, order 1
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 116, 77, 67)}
#
# (1, 116, 77, 67)
# before crop: (1, 199, 150, 284) after crop: (1, 199, 150, 284) spacing: [0.80000013 0.94599998 0.94600004]
#
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([0.79999989, 0.71700001, 0.71699935]), 'spacing_transposed': array([0.71699935, 0.79999989, 0.71700001]), 'data.shape (data is transposed)': (1, 307, 208, 161)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 111, 84, 58)}
#
# (1, 111, 84, 58)
# before: {'spacing': array([0.79999965, 0.78100002, 0.78099996]), 'spacing_transposed': array([0.78099996, 0.79999965, 0.78100002]), 'data.shape (data is transposed)': (1, 321, 217, 190)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 126, 87, 75)}
#
# (1, 126, 87, 75)
# before: {'spacing': array([0.69999993, 0.84765714, 0.84765399]), 'spacing_transposed': array([0.84765399, 0.69999993, 0.84765714]), 'data.shape (data is transposed)': (1, 290, 249, 176)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 123, 88, 75)}
#
# (1, 123, 88, 75)
# before: {'spacing': array([0.80000013, 0.94599998, 0.94600004]), 'spacing_transposed': array([0.94600004, 0.80000013, 0.94599998]), 'data.shape (data is transposed)': (1, 284, 199, 150)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 135, 80, 71)}
#
# (1, 135, 80, 71)
# prediction done
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_lowres/case_5.nii.gz
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# no separate z, order 1
# prediction done
# preprocessing kidney_paper_out_lowres/case_8.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_lowres/case_2.nii.gz
# preprocessing kidney_paper_out_lowres/case_9.nii.gz
# using preprocessor GenericPreprocessor
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# prediction done
# predicting kidney_paper_out_lowres/case_3.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# prediction done
# predicting kidney_paper_out_lowres/case_6.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# before crop: (1, 128, 174, 324) after crop: (1, 128, 174, 324) spacing: [1.24999928 0.79101509 0.79101545]
#
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# prediction done
# predicting kidney_paper_out_lowres/case_4.nii.gz
# no separate z, order 3
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# no separate z, order 3
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_lowres/case_7.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 135, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 7], [0], [0]]
# number of tiles: 2
# computing Gaussian
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.24999928, 0.79101509, 0.79101545]), 'spacing_transposed': array([0.79101545, 1.24999928, 0.79101509]), 'data.shape (data is transposed)': (1, 324, 128, 174)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 129, 80, 69)}
#
# (1, 129, 80, 69)
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 116, 77, 67)}
#
# (1, 116, 77, 67)
# prediction done
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_lowres/case_9.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 129, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 1], [0], [0]]
# number of tiles: 2
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_lowres/case_8.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# WARNING! Cannot run postprocessing because the postprocessing file is missing. Make sure to run consolidate_folds in the output folder of the model first!
# The folder you need to run this in is /content/nnUNet_trained_models/nnUNet/3d_lowres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet_trained_models/nnUNet/3d_fullres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 9 unique case ids, here are some examples: ['case_1' 'case_3' 'case_5' 'case_2' 'case_8' 'case_2' 'case_7' 'case_4'
#  'case_5']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 9
# number of cases that still need to be predicted: 9
# emptying cuda cache
# loading parameters for folds, [0]
# using the following model files:  ['/content/nnUNet_trained_models/nnUNet/3d_fullres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing kidney_paper_out_fullres/case_1.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_fullres/case_2.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_fullres/case_3.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_fullres/case_4.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_fullres/case_5.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_fullres/case_6.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 136, 135, 248) after crop: (1, 136, 135, 248) spacing: [1.         0.97655976 0.97656274]
#
# no separate z, order 3
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# before crop: (1, 145, 198, 296) after crop: (1, 145, 198, 296) spacing: [1.25000215 0.8437497  0.84375256]
#
# before crop: (1, 208, 161, 307) after crop: (1, 208, 161, 307) spacing: [0.79999989 0.71700001 0.71699935]
#
# no separate z, order 3
# before crop: (1, 249, 176, 290) after crop: (1, 249, 176, 290) spacing: [0.69999993 0.84765714 0.84765399]
#
# no separate z, order 3
# no separate z, order 3
# before crop: (1, 217, 190, 321) after crop: (1, 217, 190, 321) spacing: [0.79999965 0.78100002 0.78099996]
#
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.        , 0.97655976, 0.97656274]), 'spacing_transposed': array([0.97656274, 1.        , 0.97655976]), 'data.shape (data is transposed)': (1, 248, 136, 135)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 310, 174, 169)}
#
# (1, 310, 174, 169)
# preprocessing kidney_paper_out_fullres/case_7.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_fullres/case_1.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 310, 174, 169)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 61, 121, 182], [0, 46], [0, 41]]
# number of tiles: 16
# computing Gaussian
# before crop: (1, 199, 150, 284) after crop: (1, 199, 150, 284) spacing: [0.80000013 0.94599998 0.94600004]
#
# no separate z, order 1
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([0.79999989, 0.71700001, 0.71699935]), 'spacing_transposed': array([0.71699935, 0.79999989, 0.71700001]), 'data.shape (data is transposed)': (1, 307, 208, 161)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 282, 213, 148)}
#
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 295, 197, 170)}
#
# (1, 282, 213, 148)
# preprocessing kidney_paper_out_fullres/case_9.nii.gz
# using preprocessor GenericPreprocessor
# (1, 295, 197, 170)
# before crop: (1, 128, 174, 324) after crop: (1, 128, 174, 324) spacing: [1.24999928 0.79101509 0.79101545]
#
# no separate z, order 3
# before: {'spacing': array([0.69999993, 0.84765714, 0.84765399]), 'spacing_transposed': array([0.84765399, 0.69999993, 0.84765714]), 'data.shape (data is transposed)': (1, 290, 249, 176)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 315, 223, 191)}
#
# before: {'spacing': array([1.25000215, 0.8437497 , 0.84375256]), 'spacing_transposed': array([0.84375256, 1.25000215, 0.8437497 ]), 'data.shape (data is transposed)': (1, 296, 145, 198)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 320, 232, 214)}
#
# before: {'spacing': array([0.79999965, 0.78100002, 0.78099996]), 'spacing_transposed': array([0.78099996, 0.79999965, 0.78100002]), 'data.shape (data is transposed)': (1, 321, 217, 190)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 321, 222, 190)}
#
# (1, 315, 223, 191)
# (1, 320, 232, 214)
# (1, 321, 222, 190)
# prediction done
# no separate z, order 1
# preprocessing kidney_paper_out_fullres/case_8.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_fullres/case_3.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 282, 213, 148)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 51, 103, 154], [0, 42, 85], [0, 20]]
# number of tiles: 24
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# no separate z, order 1
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# before: {'spacing': array([0.80000013, 0.94599998, 0.94600004]), 'spacing_transposed': array([0.94600004, 0.80000013, 0.94599998]), 'data.shape (data is transposed)': (1, 284, 199, 150)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 344, 204, 182)}
#
# (1, 344, 204, 182)
# before: {'spacing': array([1.24999928, 0.79101509, 0.79101545]), 'spacing_transposed': array([0.79101545, 1.24999928, 0.79101509]), 'data.shape (data is transposed)': (1, 324, 128, 174)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 328, 205, 176)}
#
# (1, 328, 205, 176)
# no separate z, order 1
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 295, 197, 170)}
#
# (1, 295, 197, 170)
# prediction done
# predicting kidney_paper_out_fullres/case_2.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 295, 197, 170)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 56, 111, 167], [0, 34, 69], [0, 42]]
# number of tiles: 24
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_fullres/case_4.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 315, 223, 191)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 62, 125, 187], [0, 48, 95], [0, 63]]
# number of tiles: 24
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_fullres/case_5.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 320, 232, 214)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 64, 128, 192], [0, 52, 104], [0, 43, 86]]
# number of tiles: 36
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_fullres/case_6.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 321, 222, 190)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 48, 96, 145, 193], [0, 47, 94], [0, 62]]
# number of tiles: 30
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_fullres/case_7.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 344, 204, 182)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 54, 108, 162, 216], [0, 38, 76], [0, 54]]
# number of tiles: 30
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_fullres/case_9.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 328, 205, 176)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 50, 100, 150, 200], [0, 38, 77], [0, 48]]
# number of tiles: 30
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_fullres/case_8.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 295, 197, 170)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 56, 111, 167], [0, 34, 69], [0, 42]]
# number of tiles: 24
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# WARNING! Cannot run postprocessing because the postprocessing file is missing. Make sure to run consolidate_folds in the output folder of the model first!
# The folder you need to run this in is /content/nnUNet_trained_models/nnUNet/3d_fullres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# lowres_segmentations is None. Attempting to predict 3d_lowres first...
# This model expects 1 input modalities for each image
# Found 9 unique case ids, here are some examples: ['case_7' 'case_3' 'case_8' 'case_7' 'case_4' 'case_4' 'case_5' 'case_7'
#  'case_2']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 9
# number of cases that still need to be predicted: 9
# emptying cuda cache
# loading parameters for folds, [0]
# using the following model files:  ['/content/nnUNet_trained_models/nnUNet/3d_lowres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_1.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_2.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_3.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_4.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_5.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_6.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 136, 135, 248) after crop: (1, 136, 135, 248) spacing: [1.         0.97655976 0.97656274]
#
# no separate z, order 3
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# before crop: (1, 208, 161, 307) after crop: (1, 208, 161, 307) spacing: [0.79999989 0.71700001 0.71699935]
#
# before crop: (1, 145, 198, 296) after crop: (1, 145, 198, 296) spacing: [1.25000215 0.8437497  0.84375256]
#
# no separate z, order 3
# before crop: (1, 249, 176, 290) after crop: (1, 249, 176, 290) spacing: [0.69999993 0.84765714 0.84765399]
#
# no separate z, order 3
# no separate z, order 1
# no separate z, order 3
# before: {'spacing': array([1.        , 0.97655976, 0.97656274]), 'spacing_transposed': array([0.97656274, 1.        , 0.97655976]), 'data.shape (data is transposed)': (1, 248, 136, 135)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 122, 68, 66)}
#
# (1, 122, 68, 66)
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_7.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_1.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# before crop: (1, 217, 190, 321) after crop: (1, 217, 190, 321) spacing: [0.79999965 0.78100002 0.78099996]
#
# no separate z, order 1
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 116, 77, 67)}
#
# before crop: (1, 199, 150, 284) after crop: (1, 199, 150, 284) spacing: [0.80000013 0.94599998 0.94600004]
# (1, 116, 77, 67)
#
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_8.nii.gz
# using preprocessor GenericPreprocessor
# no separate z, order 3
# no separate z, order 1
# before: {'spacing': array([0.79999989, 0.71700001, 0.71699935]), 'spacing_transposed': array([0.71699935, 0.79999989, 0.71700001]), 'data.shape (data is transposed)': (1, 307, 208, 161)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 111, 84, 58)}
#
# (1, 111, 84, 58)
# before: {'spacing': array([1.25000215, 0.8437497 , 0.84375256]), 'spacing_transposed': array([0.84375256, 1.25000215, 0.8437497 ]), 'data.shape (data is transposed)': (1, 296, 145, 198)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 125, 91, 84)}
#
# (1, 125, 91, 84)
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# no separate z, order 1
# before: {'spacing': array([0.69999993, 0.84765714, 0.84765399]), 'spacing_transposed': array([0.84765399, 0.69999993, 0.84765714]), 'data.shape (data is transposed)': (1, 290, 249, 176)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 123, 88, 75)}
#
# (1, 123, 88, 75)
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([0.79999965, 0.78100002, 0.78099996]), 'spacing_transposed': array([0.78099996, 0.79999965, 0.78100002]), 'data.shape (data is transposed)': (1, 321, 217, 190)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 126, 87, 75)}
#
# (1, 126, 87, 75)
# before: {'spacing': array([0.80000013, 0.94599998, 0.94600004]), 'spacing_transposed': array([0.94600004, 0.80000013, 0.94599998]), 'data.shape (data is transposed)': (1, 284, 199, 150)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 135, 80, 71)}
#
# (1, 135, 80, 71)
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 116, 77, 67)}
#
# (1, 116, 77, 67)
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_2.nii.gz
# preprocessing kidney_paper_out_cascade/3d_lowres_predictions/case_9.nii.gz
# using preprocessor GenericPreprocessor
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# no separate z, order 1
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_3.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# before crop: (1, 128, 174, 324) after crop: (1, 128, 174, 324) spacing: [1.24999928 0.79101509 0.79101545]
#
# no separate z, order 3
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_5.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_4.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_6.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# before: {'spacing': array([1.24999928, 0.79101509, 0.79101545]), 'spacing_transposed': array([0.79101545, 1.24999928, 0.79101509]), 'data.shape (data is transposed)': (1, 324, 128, 174)}
# after:  {'spacing': array([1.990695  , 1.99066952, 1.99066952]), 'data.shape (data is resampled)': (1, 129, 80, 69)}
#
# (1, 129, 80, 69)
# prediction done
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_7.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 135, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 7], [0], [0]]
# number of tiles: 2
# computing Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_8.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 128, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0], [0], [0]]
# number of tiles: 1
# prediction done
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# predicting kidney_paper_out_cascade/3d_lowres_predictions/case_9.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 129, 128, 128)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 1], [0], [0]]
# number of tiles: 2
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# WARNING! Cannot run postprocessing because the postprocessing file is missing. Make sure to run consolidate_folds in the output folder of the model first!
# The folder you need to run this in is /content/nnUNet_trained_models/nnUNet/3d_lowres/Task135_KiTS2021/nnUNetTrainerV2__nnUNetPlansv2.1
# 3d_lowres done
# using model stored in  /content/nnUNet_trained_models/nnUNet/3d_cascade_fullres/Task135_KiTS2021/nnUNetTrainerV2CascadeFullRes__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 9 unique case ids, here are some examples: ['case_1' 'case_4' 'case_9' 'case_5' 'case_2' 'case_1' 'case_6' 'case_5'
#  'case_6']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 9
# number of cases that still need to be predicted: 9
# emptying cuda cache
# loading parameters for folds, [0]
# using the following model files:  ['/content/nnUNet_trained_models/nnUNet/3d_cascade_fullres/Task135_KiTS2021/nnUNetTrainerV2CascadeFullRes__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing kidney_paper_out_cascade/case_1.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/case_2.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/case_3.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/case_4.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/case_5.nii.gz
# using preprocessor GenericPreprocessor
# preprocessing kidney_paper_out_cascade/case_6.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 136, 135, 248) after crop: (1, 136, 135, 248) spacing: [1.         0.97655976 0.97656274]
#
# no separate z, order 3
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# before crop: (1, 145, 198, 296) after crop: (1, 145, 198, 296) spacing: [1.25000215 0.8437497  0.84375256]
#
# before crop: (1, 208, 161, 307) after crop: (1, 208, 161, 307) spacing: [0.79999989 0.71700001 0.71699935]
#
# no separate z, order 3
# before crop: (1, 249, 176, 290) after crop: (1, 249, 176, 290) spacing: [0.69999993 0.84765714 0.84765399]
#
# no separate z, order 3
# no separate z, order 3
# before crop: (1, 217, 190, 321) after crop: (1, 217, 190, 321) spacing: [0.79999965 0.78100002 0.78099996]
#
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.        , 0.97655976, 0.97656274]), 'spacing_transposed': array([0.97656274, 1.        , 0.97655976]), 'data.shape (data is transposed)': (1, 248, 136, 135)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 310, 174, 169)}
#
# before: {'spacing': array([0.79999989, 0.71700001, 0.71699935]), 'spacing_transposed': array([0.71699935, 0.79999989, 0.71700001]), 'data.shape (data is transposed)': (1, 307, 208, 161)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 282, 213, 148)}
#
# no separate z, order 1
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 295, 197, 170)}
#
# no separate z, order 1
# (4, 310, 174, 169)
# preprocessing kidney_paper_out_cascade/case_7.nii.gz
# using preprocessor GenericPreprocessor
# no separate z, order 1
# predicting kidney_paper_out_cascade/case_1.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 310, 174, 169)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 61, 121, 182], [0, 46], [0, 41]]
# number of tiles: 16
# computing Gaussian
# before crop: (1, 199, 150, 284) after crop: (1, 199, 150, 284) spacing: [0.80000013 0.94599998 0.94600004]
#
# no separate z, order 3
# (4, 282, 213, 148)
# preprocessing kidney_paper_out_cascade/case_9.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 128, 174, 324) after crop: (1, 128, 174, 324) spacing: [1.24999928 0.79101509 0.79101545]
#
# no separate z, order 3
# (4, 295, 197, 170)
# before: {'spacing': array([0.69999993, 0.84765714, 0.84765399]), 'spacing_transposed': array([0.84765399, 0.69999993, 0.84765714]), 'data.shape (data is transposed)': (1, 290, 249, 176)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 315, 223, 191)}
#
# before: {'spacing': array([1.25000215, 0.8437497 , 0.84375256]), 'spacing_transposed': array([0.84375256, 1.25000215, 0.8437497 ]), 'data.shape (data is transposed)': (1, 296, 145, 198)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 320, 232, 214)}
#
# before: {'spacing': array([0.79999965, 0.78100002, 0.78099996]), 'spacing_transposed': array([0.78099996, 0.79999965, 0.78100002]), 'data.shape (data is transposed)': (1, 321, 217, 190)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 321, 222, 190)}
#
# prediction done
# preprocessing kidney_paper_out_cascade/case_8.nii.gz
# using preprocessor GenericPreprocessor
# predicting kidney_paper_out_cascade/case_3.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 282, 213, 148)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 51, 103, 154], [0, 42, 85], [0, 20]]
# number of tiles: 24
# using precomputed Gaussian
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# before crop: (1, 192, 152, 264) after crop: (1, 192, 152, 264) spacing: [0.79999959 0.87299997 0.87300003]
#
# no separate z, order 3
# no separate z, order 1
# (4, 321, 222, 190)
# no separate z, order 1
# (4, 315, 223, 191)
# (4, 320, 232, 214)
# before: {'spacing': array([0.80000013, 0.94599998, 0.94600004]), 'spacing_transposed': array([0.94600004, 0.80000013, 0.94599998]), 'data.shape (data is transposed)': (1, 284, 199, 150)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 344, 204, 182)}
#
# before: {'spacing': array([1.24999928, 0.79101509, 0.79101545]), 'spacing_transposed': array([0.79101545, 1.24999928, 0.79101509]), 'data.shape (data is transposed)': (1, 324, 128, 174)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 328, 205, 176)}
#
# no separate z, order 1
# prediction done
# predicting kidney_paper_out_cascade/case_2.nii.gz
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 295, 197, 170)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 56, 111, 167], [0, 34, 69], [0, 42]]
# number of tiles: 24
# using precomputed Gaussian
# no separate z, order 1
# before: {'spacing': array([0.79999959, 0.87299997, 0.87300003]), 'spacing_transposed': array([0.87300003, 0.79999959, 0.87299997]), 'data.shape (data is transposed)': (1, 264, 192, 152)}
# after:  {'spacing': array([0.78126, 0.78125, 0.78125]), 'data.shape (data is resampled)': (1, 295, 197, 170)}
#
# (4, 344, 204, 182)
# (4, 328, 205, 176)
# (4, 295, 197, 170)
# prediction done
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# predicting kidney_paper_out_cascade/case_6.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 321, 222, 190)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 48, 96, 145, 193], [0, 47, 94], [0, 62]]
# number of tiles: 30
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# predicting kidney_paper_out_cascade/case_4.nii.gz
# no separate z, order 1
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 315, 223, 191)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 62, 125, 187], [0, 48, 95], [0, 63]]
# number of tiles: 24
# using precomputed Gaussian
# prediction done
# This worker has ended successfully, no errors to report
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# predicting kidney_paper_out_cascade/case_5.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 320, 232, 214)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 64, 128, 192], [0, 52, 104], [0, 43, 86]]
# number of tiles: 36
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# predicting kidney_paper_out_cascade/case_7.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 344, 204, 182)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 54, 108, 162, 216], [0, 38, 76], [0, 54]]
# number of tiles: 30
# using precomputed Gaussian
# no separate z, order 1
# prediction done
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# predicting kidney_paper_out_cascade/case_9.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 328, 205, 176)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 50, 100, 150, 200], [0, 38, 77], [0, 48]]
# number of tiles: 30
# using precomputed Gaussian
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# predicting kidney_paper_out_cascade/case_8.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (4, 295, 197, 170)
# patch size: [128 128 128]
# steps (x, y, and z): [[0, 56, 111, 167], [0, 34, 69], [0, 42]]
# number of tiles: 24
# using precomputed Gaussian
# no separate z, order 1
# prediction done
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# This worker has ended successfully, no errors to report
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: False lowres axis None
# no separate z, order 1
# WARNING! Cannot run postprocessing because the postprocessing file is missing. Make sure to run consolidate_folds in the output folder of the model first!
# The folder you need to run this in is /content/nnUNet_trained_models/nnUNet/3d_cascade_fullres/Task135_KiTS2021/nnUNetTrainerV2CascadeFullRes__nnUNetPlansv2.1

# %% [markdown]
# # Calculate Dice metrics

# %%
import json
import os
import torch
import monai

KIDNEY_DATASET = f'dataset.json'
DATASET_ROOT = os.getcwd()

with open(KIDNEY_DATASET, 'r') as f:
    dataset_json = json.load(f)

validation_with_root = [{
                          'artery':obj['artery'],
                         'vein':obj['vein'],
                         'excret':obj['excret'],
                         'label':obj['label']
                        } for obj in dataset_json['validation']]

load = monai.transforms.LoadImage()
replace_labels = monai.transforms.MapLabelValue(orig_labels=[0,1,2,3,4,5,6], target_labels=[0,0,0,0,2,2,1])
replace_labels_nn = monai.transforms.MapLabelValue(orig_labels=[0,1,2,3], target_labels=[0,1,2,2])
ensure = monai.transforms.EnsureType()
as_discrete = monai.transforms.Compose(
    [
        monai.transforms.AddChannel(), # Channel
    monai.transforms.AsDiscrete(to_onehot=3),
    monai.transforms.AddChannel() # Batch
    ])

# %%
ROOT = 'kidney_paper_out_fullres'
dices = []
header = ['Study', 'Kidney', 'Neoplasm']
print('| {:^43} |'.format('Dice metric statistics fullres'))
print('='*47)
print('| {:^6} | {:} | {:} |'.format(*header))

for case in validation_with_root:
    fio = case['label'].split('/')[-2]
    data = load(case['label'])
    data = as_discrete(ensure(replace_labels(data[0]))), data[1]
    pred_data = load(f'{ROOT}/{fio}.nii.gz')
    pred_data = as_discrete(replace_labels_nn(ensure(pred_data[0]))), pred_data[1]
    dice = monai.metrics.compute_meandice(pred_data[0], data[0], False)
    dices.append(dice)
    print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*[fio, dice[0,0].cpu().item(), dice[0,1].cpu().item()]))
print('-'*30)
print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*['Avg.', torch.cat(dices).mean(0)[0].cpu().item(), torch.cat(dices).mean(0)[1].cpu().item()]))
print('-'*30)
print('| Mean = {:^19.2f} |'.format(torch.cat(dices).mean().cpu().item()))
# Out:
# |       Dice metric statistics fullres        |
# ===============================================
# | Study  | Kidney | Neoplasm |
# | case_1 |  0.71  |   0.92   |
# | case_2 |  0.65  |   0.84   |
# | case_3 |  0.74  |   0.00   |
# | case_4 |  0.75  |   0.92   |
# | case_5 |  0.72  |   0.84   |
# | case_6 |  0.65  |   0.00   |
# | case_7 |  0.73  |   0.00   |
# | case_8 |  0.65  |   0.84   |
# | case_9 |  0.71  |   0.94   |
# ------------------------------
# |  Avg.  |  0.70  |   0.59   |
# ------------------------------
# | Mean =        0.65         |

# %%
ROOT = 'kidney_paper_out_lowres'
dices = []
header = ['Study', 'Kidney', 'Neoplasm']
print('| {:^43} |'.format('Dice metric statistics lowres'))
print('='*47)
print('| {:^6} | {:} | {:} |'.format(*header))

for case in validation_with_root:
    fio = case['label'].split('/')[-2]
    data = load(case['label'])
    data = as_discrete(ensure(replace_labels(data[0]))), data[1]
    pred_data = load(f'{ROOT}/{fio}.nii.gz')
    pred_data = as_discrete(replace_labels_nn(ensure(pred_data[0]))), pred_data[1]
    dice = monai.metrics.compute_meandice(pred_data[0], data[0], False)
    dices.append(dice)
    print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*[fio, dice[0,0].cpu().item(), dice[0,1].cpu().item()]))
print('-'*30)
print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*['Avg.', torch.cat(dices).mean(0)[0].cpu().item(), torch.cat(dices).mean(0)[1].cpu().item()]))
print('-'*30)
print('| Mean = {:^19.2f} |'.format(torch.cat(dices).mean().cpu().item()))
# Out:
# |        Dice metric statistics lowres        |
# ===============================================
# | Study  | Kidney | Neoplasm |
# | case_1 |  0.49  |   0.00   |
# | case_2 |  0.68  |   0.72   |
# | case_3 |  0.73  |   0.00   |
# | case_4 |  0.78  |   0.21   |
# | case_5 |  0.72  |   0.84   |
# | case_6 |  0.64  |   0.00   |
# | case_7 |  0.75  |   0.00   |
# | case_8 |  0.68  |   0.72   |
# | case_9 |  0.75  |   0.85   |
# ------------------------------
# |  Avg.  |  0.69  |   0.37   |
# ------------------------------
# | Mean =        0.53         |

# %%
ROOT = 'kidney_paper_out_cascade'
dices = []
header = ['Study', 'Kidney', 'Neoplasm']
print('| {:^43} |'.format('Dice metric statistics cascade'))
print('='*47)
print('| {:^6} | {:} | {:} |'.format(*header))

for case in validation_with_root:
    fio = case['label'].split('/')[-2]
    data = load(case['label'])
    data = as_discrete(ensure(replace_labels(data[0]))), data[1]
    pred_data = load(f'{ROOT}/{fio}.nii.gz')
    pred_data = as_discrete(replace_labels_nn(ensure(pred_data[0]))), pred_data[1]
    dice = monai.metrics.compute_meandice(pred_data[0], data[0], False)
    dices.append(dice)
    print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*[fio, dice[0,0].cpu().item(), dice[0,1].cpu().item()]))
print('-'*30)
print('| {:^6} | {:^6.2f} | {:^8.2f} |'.format(*['Avg.', torch.cat(dices).mean(0)[0].cpu().item(), torch.cat(dices).mean(0)[1].cpu().item()]))
print('-'*30)
print('| Mean = {:^19.2f} |'.format(torch.cat(dices).mean().cpu().item()))
# Out:
# |       Dice metric statistics cascade        |
# ===============================================
# | Study  | Kidney | Neoplasm |
# | case_1 |  0.51  |   0.33   |
# | case_2 |  0.65  |   0.81   |
# | case_3 |  0.74  |   0.00   |
# | case_4 |  0.77  |   0.33   |
# | case_5 |  0.72  |   0.83   |
# | case_6 |  0.65  |   0.00   |
# | case_7 |  0.73  |   0.00   |
# | case_8 |  0.65  |   0.81   |
# | case_9 |  0.71  |   0.93   |
# ------------------------------
# |  Avg.  |  0.68  |   0.45   |
# ------------------------------
# | Mean =        0.57         |
